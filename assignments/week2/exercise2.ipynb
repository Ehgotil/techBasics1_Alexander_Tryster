# %% [markdown]
# ### General Info on Python
#
# The Python syntax we are learning in this class is Python3. In 2025, most people are using Python3, but you should know that before Python3 there was Python2, and it has slightly different syntax that is not compatible with Python3. If you ever came across some old code examples and realised that it gives you error messages in your Python3 environment, the reason might be it was written in Python2.
#
# The easiest way to identify if a Python program is written in Python2 is through the print function.
#
# Last week, we learnt about print function in Python3 and it looks like this:

# %%
print("hello again!")

# %% [markdown]
# But in Python2, the same function looks like this:

# %%
print ("hello again!")
# Out:
# hello again!

# %% [markdown]
# Another note on Python3 and printing is that by default all Python3 text objects use UTF-8 internally. Which means you can print any weird symbols supported by UTF-8 without extra effort. (Which is not the case with Python2)

# %%
print("🤨😶😐")
# Out:
# 🤨😶😐

# %% [markdown]
# If you are interested to know more about the history and the differences between the two, you can checkout [this link](https://www.datacamp.com/blog/python-2-vs-3-everything-you-need-to-know)

# %% [markdown]
# ---
# ### Variables
#
# In math, a variable is a letter that represents an unknown number. Ex: `1 + x  = 4.` In programming, variables are more like holders that can store any information that will be needed later in the program's execution. The value stored in the variable changes each time the variable is assigned a new value.
#
# In Python, variables are more flexible than programming languages such as C. It is possible to assign different data types to the same variable and it's type changes automatically. You can use the function `type()` to find out the data type of any expression.

# %%
x = 1
print("The current value of X is: ", x, ". Data type is: ", type(x))
x = "amazing"
print("The current value of X is: ", x, ". Data type is: ", type(x))
x = True
print("The current value of X is: ", x, ". Data type is: ", type(x))
x= [1,2,3]
print("The current value of X is: ", x, ". Data type is: ", type(x))
# Out:
# The current value of X is:  1 . Data type is:  <class 'int'>
# The current value of X is:  amazing . Data type is:  <class 'str'>
# The current value of X is:  True . Data type is:  <class 'bool'>
# The current value of X is:  [1, 2, 3] . Data type is:  <class 'list'>

# %% [markdown]
# You can also convert data types based on your need

# %%
result = 13 * 11
print(result, type(result))

result = str(result) # here we are using str() to convert result from int to string
print(result, type(result))
# Out:
# 143 <class 'int'>
# 143 <class 'str'>

# %% [markdown]
# Variables are also useful to take user inputs and save them for later.

# %%
something = input("Type something: ")
print("You typed:", something)
print(type(something))
# Out:
# You typed:
# <class 'str'>

# %% [markdown]
# Notice inputs are by default strings. If we need users to input some numbers, we will need to manually convert them into int in the code.

# %%
number1 = input("Enter the first number: ")
number2 = input("Enter the second number: ")
print(number1 + number2)
print(int(number1) + int(number2))
# Out:
# 1
# 7
# 8

# %% [markdown]
# We learnt that `=` is an assignment operator and  `==` really means equal. There are more special assignment operators that combines assignment with algorithmic operators. What should the following code print out?

# %%
x = 1
x += 3
print(x)
x -= 1
print(x)
# Out:
# 4
# 3

# %% [markdown]
# ---
# ### More about Print statement

# %% [markdown]
# We have been defining strings with either double quotes or single quotes. What if you want to print both double quotes and single quotes in one string? In such cases you can *escape* special characters by putting a backslash `\` before. For example:

# %%
print("The teacher said. \"I think that's a cool idea!\"")
# Out:
# The teacher said. "I think that's a cool idea!"

# %% [markdown]
# See how the escaped characters got rendered in a different color in your code editor.
#
# They are called escape characters because they are escaped from their usual meaning. There are some other useful escape characters that are commonly used:
#
# - `\n` for new line in your string
# - `\t` for adding a tab in your string
# - `\\` you will need to escape your backslash if you want to print one

# %% [markdown]
# How many backslash will you get in the end?

# %%
print("\\\\\\\\\n\\\\\\\\")
# Out:
# \\\\
# \\\\

# %% [markdown]
# Some algorithmic Operations can also be applied to strings

# %%
print("!" * 3)
print("a" + "b")
print("10" + "10")

# %% [markdown]
# Strings have length, and you can use `len()` to get  the length of your string.

# %%
print(len("How many characters are there in this long ass sentence?)"))
print(len("\n"))
# Out:
# 57
# 1

# %% [markdown]
# You can also transform a string to make sure you only have uppercase or lowercase in your string.

# %%
print('uppercase'.upper())
print('Lowercase'.lower())
# Out:
# UPPERCASE
# lowercase

# %% [markdown]
# Another very useful trick that can be combined with print command is the f-string, formatted string. A formatted string looks like this:

# %%
program = "Cultural Studies"
semester = 7
print(f"I study {program} in semester {semester}.")
# Out:
# I study Cultural Studies in semester 7.

# %% [markdown]
# By using the f-string we can print a string with multiple variables without worrying about their data type.

# %% [markdown]
# #### Task 1
# Correct the following code cells with minimal changes:

# %%
bool = True
if bool:
    print("True!")
# Out:
# True!

# %%
result = 14 * 4
print("The result is", result)
# Out:
# The result is 56

# %% [markdown]
# ---

# %% [markdown]
# ### Conditional Statements

# %% [markdown]
# Conditional statements are there for us to control the flow of execution by evaluating whether a condition is true or false. Everything indented the same amount after the colon (:) will be executed whenever the condition is true.

# %%
season = "winter"
mood = "Feeling okay."

if season == "summer":
    print("Time to enjoy the sun.")
    mood = "Feeling happy."

print(mood)
# Out:
# Feeling okay.

# %% [markdown]
#  After the colon we always need to have a line break and indent the next line of code. If you type an if statement in PyCharm, once you hit enter, the indent is automatically added for you. Just to show the wrong example, the same syntax without indent won't work in Python:

# %%
if season == "summer":
    print("Time to enjoy the sun.")

# %% [markdown]
# You can chain multiple conditions up like this:

# %%
season = "summer"
mood = "good"

if season == "summer" or mood == "good":
    print("Let's go out!")

if season == "winter" and mood == "bad":
    print("Let's stay home.")
# Out:
# Let's go out!

# %% [markdown]
# An if statement can also be combined with an else statement, which handles all the other cases when the if statement is not fulfilled.

# %%
temperature = 5

if temperature > 0:
    print("no ice")
else:
    print("frozen")
# Out:
# no ice

# %% [markdown]
# One can also nest multiple conditional statements. Correct indent is very important here for the parser to know which statements go together.

# %%
temperature = -1

if temperature > 0:
    if temperature >= 30:
        print("too hot")
    elif temperature < 10:
        print("too cold")
    else:
        print("comfortable")
else:
    print("frozen!")
# Out:
# frozen!

# %% [markdown]
# Conditional statements are very handy when handling user input.

# %%
number = int(input("Please type in a number: "))

if number < 0:
    print("The number is negative.")
elif number == 0:
    print("The number is zero.")
else:
    print("The number is positive.")
# Out:
# The number is negative.

# %% [markdown]
# #### Task 2
# Complete the code below with conditional statements. It shall print out the largest number among three numbers:

# %%
# You can edit the numbers to test your code
n1 = 89
n2 = 48
n3 = 23

# Write your code here!
if n1 > n2:
    greatest = n1
else:
    greatest = n2


if n3 > greatest:
    greatest = n3

print("The largest number is:", greatest)
# Out:
# The largest number is: 89

# %%
# You can edit the numbers to test your code
n1 = 83297
n2 = 4356654557
n3 = 2343


if n1 > n2 and n3:
    print(f"The largest number is {n1}")

elif n2 > n3:
    print(f"The largest number is {n2}")

else:
    print(f"The largest number is {n3}")
# Out:
# The largest number is 4356654557

# %% [markdown]
# #### Task 3
#
# Please write a small program that asks for the user's age. Check the following criteria and print some text for feedbacks:
# 1) If it is possible for a human to have such an age
# 2) If the user is an adult, then print "Adult Price"; If not, print "Discount Price"
#
# Challenge: If it is a valid number

# %%
age = input("Enter your age:")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 age = input("Enter your age:")
#
# TypeError: 'int' object is not callable

# %%
age = input("Enter your age:")

for age in range (120):
    print("You are dead or not alive yet, lil old bro")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 age = input("Enter your age:")
#       2
#       3 for age in range (120):
#       4     print("You are dead or not alive yet, lil old bro")
#
# TypeError: 'int' object is not callable

# %%
age = input("Enter your age:")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 age = input("Enter your age:")
#
# File ~/PycharmProjects/techBasics1_2026/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/PycharmProjects/techBasics1_2026/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# ---

# %%
age = input("Enter your age:")

for age in range (1,120):
    print("You are dead or not alive yet, lil old bro")
# Out:
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# You are dead or not alive yet, lil old bro
# ...

# %% [markdown]
# ## Assignment 2
#
# Your assignment this week is to create a little text game using Python. To make it a bit more interesting, let's learn a few extra things.

# %% [markdown]
# ### Timer
# To make your text game more interactive, let's learn some simple tricks.
# For that one need to first import the time library.

# %%
import time # import the time library

# %% [markdown]
# Now try to run the following code and see what's going to happen.

# %%
print("1")
time.sleep(1) # delay 1 second
print("2")
time.sleep(1)
print("3")
# Out:
# 1
# 2
# 3

# %% [markdown]
# You can use this to time your print commands.

# %% [markdown]
# ### Simple Loop: While

# %% [markdown]
# Another techniques that comes in handy when handling user input is to use a while loop. We will learn more about loops next week. While loop is useful when you want to make sure the users follow exactly what you ask them to do:

# %%
while True:
    number = int(input("Please type in a number, -1 to quit: "))

    if number == -1:
        break

    print(number ** 2)

print("Thanks and bye!")
# Out:
# Thanks and bye!

# %% [markdown]
# ---
# #### How to run Python code in PyCharm?
# Right click on your `.py` file and click on `▷ Run`. Or use the keyboard shortcut CTRL+SHIFT+R.
#
# Run the sample `game.py` file in PyCharm and see how it looks like.

# %% [markdown]
# ---
# ### Debugging
# Very often when we test the code we wrote, we encounter error messages:

# %%
x = 10
y = 0
result = x / y

print(f"{x} divided by {y} is {result}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 x = 10
#       2 y = 0
# ----> 3 result = x / y
#       4
#       5 print(f"{x} divided by {y} is {result}")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# It is important to stay calm and read what is being written in the error message. Usually it states the line of code as well as the reason that is causing the error.
#
# But there are other cases when the program runs without errors, but they don't really do what we intend them to do :/. Now what we need is <i>debugging</i>: the process discovering the causes of bugs. People who code often spend more time debugging than writing fresh code.
#
# A simple yet effective way of debugging is adding print statements to your code. With print statements, we can check the current state of variables and see if they are actually behaving as what we have in mind.

# %%
# let's say we have a little game
growingRate = 1
season = "summer"

if season == "Summer":
    growingRate * 2

print("Growing rate is:", growingRate)
# Out:
# Growing rate is: 1

# %% [markdown]
# Seems like our growing rate is not doubled as we expected. What debugging print statements can we add here?

# %%
# let's say we have a little game
growingRate = 1
season = "summer"

print("Condition:", season == "Summer")
if season == "Summer":
    growingRate * 2

print("Growing rate is:", growingRate)
# Out:
# Condition: False
# Growing rate is: 1

# %% [markdown]
# By checking the value of the condition, we realize that the condition is never met. Now it is also easier to notice that "summer" and "Summer" are not the same, so we need to change one of the strings to make this work. After fixing the condition, the code is still behaving the same. Now it's time to add another print statement inside the if statement to check what's going on with `growingRate`.

# %%
# let's say we have a little game
growingRate = 1
season = "summer"

# print("Condition:", season == "Summer")
if season == "summer":
    growingRate * 2
    print(growingRate)

print("Growing rate is:", growingRate)
# Out:
# 1
# Growing rate is: 1

# %% [markdown]
# Checking the output, we can say that the program can finally go inside the if statement. The value of growingRate has not been changed here because we never assigned the doubled value to the variable.

# %%
# let's say we have a little game
growingRate = 1
season = "summer"

# print("Condition:", season == "Summer")
if season == "summer":
    growingRate = growingRate * 2
    # print(growingRate)

print("Growing rate is:", growingRate)
# Out:
# Growing rate is: 2

# %% [markdown]
# After fixing everything, remember to remove the print statements for debugging purpose. Simple bugs like this one might also be identified easily just by reading carefully. This is a simple demo to show when and how printing statements can be used for debugging.

# %% [markdown]
# Another useful tip for debugging your text game:

# %%
print("Welcome to test game")
name = input("What's your name? ")
print("Welcome", name)
number = input("What's your favorite number? ")
print("You like", number)
# Out:
# Welcome to test game
# Welcome test

# %% [markdown]
# In your game you will need to ask for inputs from the user, which makes testing slow and cumbersome. Each time the program is tested, input must be typed in.
# One way around this is "hard-coding" the input while testing.

# %%
print("Welcome to test game")
# name = input("What's your name? ")
name = "Lily"
print("Welcome", name)
# number = input("What's your favorite number? ")
number = 7
print("You like", number)
# Out:
# Welcome to test game
# Welcome Lily
# You like 7

# %% [markdown]
# These are very basic debugging techniques, we will introduce more techniques as we learn more things in this class and your program gets more complicated!
